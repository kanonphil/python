# %%
print(1)
# Out:
# 1

# %% [markdown]
# python

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# Hello

# %% [markdown]
# #은 h1~h6 태그의 역할을 함
# # 안녕하세요
# ## 안녕하세요
# ### 안녕하세요
#
# ###### 공백을 2번 쓰면 줄 개행
# 첫 번째 줄
# 두 번째 줄
